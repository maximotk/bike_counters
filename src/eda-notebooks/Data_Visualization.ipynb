# %% [markdown]
# # RAMP on predicting cyclist traffic in Paris
#
#
# ## Introduction
#
# The dataset was collected with cyclist counters installed by Paris city council in multiple locations. It contains hourly information about cyclist traffic, as well as the following features,
#  - counter name
#  - counter site name
#  - date
#  - counter installation date
#  - latitude and longitude
#
# Available features are quite scarce. However, **we can also use any external data that can help us to predict the target variable.**

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# # Loading the data with pandas
#
# First, download the data files from Kaggle, and put them to into the data folder.
#
#
# Data is stored in [Parquet format](https://parquet.apache.org/), an efficient columnar data format. We can load the train set with pandas,

# %%
data = pd.read_parquet(Path("data") / "train.parquet")
data.head()

data_test = pd.read_parquet(Path("data") / "final_test.parquet")
data["date"]
# Out:
# 48321    2020-09-01 02:00:00
# 48324    2020-09-01 03:00:00
# 48327    2020-09-01 04:00:00
# 48330    2020-09-01 15:00:00
# 48333    2020-09-01 18:00:00
#                  ...
# 929175   2021-09-09 06:00:00
# 929178   2021-09-09 10:00:00
# 929181   2021-09-09 15:00:00
# 929184   2021-09-09 22:00:00
# 929187   2021-09-09 23:00:00
# Name: date, Length: 496827, dtype: datetime64[us]

# %% [markdown]
# # Visualizing the data
#
#
# Let's visualize the data, starting from the spatial distribution of counters on the map

# %%
import folium

m = folium.Map(location=data[["latitude", "longitude"]].mean(axis=0), zoom_start=13)

for _, row in (
    data[["counter_name", "latitude", "longitude"]]
    .drop_duplicates("counter_name")
    .iterrows()
):
    folium.Marker(
        row[["latitude", "longitude"]].values.tolist(), popup=row["counter_name"]
    ).add_to(m)

m
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/bike_counters/lib/python3.13/site-packages/folium/utilities.py:86: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc7a16f29bb62a73743821d73fed67ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc7a16f29bb62a73743821d73fed67ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc7a16f29bb62a73743821d73fed67ec = L.map(
#                 &quot;map_dc7a16f29bb62a73743821d73fed67ec&quot;,
#                 {
#                     center: [48.854343481348636, 2.3454791459683153],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9972eea58fee1bc9fd44150b2407dd37 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9972eea58fee1bc9fd44150b2407dd37.addTo(map_dc7a16f29bb62a73743821d73fed67ec);
#
#
#             var marker_603d07f4e471a1b4adfec08bb3724c2c = L.marker(
#                 [48.846028, 2.375429],
#                 {}
#             ).addTo(map_dc7a16f29bb62a73743821d73fed67ec);
#
#
#         var popup_a9f72a8804b8828462db752391a9883e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e28b44b0ac85f4864bf147e61187911 = $(`&lt;div id=&quot;html_8e28b44b0ac85f4864bf147e61187911&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;28 boulevard Diderot E-O&lt;/div&gt;`)[0];
#                 popup_a9f72a8804b8828462db752391a9883e.setContent(html_8e28b44b0ac85f4864bf147e61187911);
#
#
#
#         marker_603d07f4e471a1b4adfec08bb3724c2c.bindPopup(popup_a9f72a8804b8828462db752391a9883e)
#         ;
#
#
#
#
#             var marker_88e4139a85ac59e40abab00f1d2daa5b = L.marker(
#                 [48.846028, 2.375429],
#                 {}
#             ).addTo(map_dc7a16f29bb62a73743821d73fed67ec);
#
#
#         var popup_2637b26e4122c7922cf78432df6ee8de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7637f9780f1e264ac5d44ac4bd55b0ce = $(`&lt;div id=&quot;html_7637f9780f1e264ac5d44ac4bd55b0ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;28 boulevard Diderot O-E&lt;/div&gt;`)[0];
#                 popup_2637b26e4122c7922cf78432df6ee8de.setContent(html_7637f9780f1e264ac5d44ac4bd55b0ce);
#
#
#
#         marker_88e4139a85ac59e40abab00f1d2daa5b.bindPopup(popup_2637b26e4122c7922cf78432df6ee8de)
#         ;
#
#
#
#
#             var marker_f9889667a65547189e6dd3cb51e981fd = L.marker(
#                 [48.83436, 2.377],
#                 {}
#             ).addTo(map_dc7a16f29bb62a73743821d73fed67ec);
#
#
#         var popup_5e13676c62ea216b413987b437ac01f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_98e91d5c1fe876a242e9b59967ba8419 = $(`&lt;div id=&quot;html_98e91d5c1fe876a242e9b59967ba8419&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;39 quai François Mauriac NO-SE&lt;/div&gt;`)[0];
#                 popup_5e13676c62ea216b413987b437ac01f7.setContent(html_98e91d5c1fe876a242e9b59967ba8419);
#
#
#
#         marker_f9889667a65547189e6dd3cb51e981fd.bindPopup(popup_5e13676c62ea216b413987b437ac01f7)
#         ;
#
#
#
#
#             var marker_db0fdf2e3a32a2100bb9049f3a9e07e4 = L.marker(
#                 [48.83436, 2.377],
#                 {}
#             ).addTo(map_dc7a16f29bb62a73743821d73fed67ec);
#
#
#         var popup_04830997bb21b1032f75796fc1e93169 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2eb5a3bfbcaea77adfdbfbbd07b9bbfe = $(`&lt;div id=&quot;html_2eb5a3bfbcaea77adfdbfbbd07b9bbfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;39 quai François Mauriac SE-NO&lt;/div&gt;`)[0];
#                 popup_04830997bb21b1032f75796fc1e93169.setContent(html_2eb5a3bfbcaea77adfdbfbbd07b9bbfe);
#
#
#
#         marker_db0fdf2e3a32a2100bb9049f3a9e07e4.bindPopup(popup_04830997bb21b1032f75796fc1e93169)
#         ;
#
#
#
#
#             var marker_c388adaca43286ad257e007acd9d20f6 = L.marker(
#                 [48.85372, 2.35702],
#                 {}
#             ).addTo(map_dc7a16f29bb62a73743821d73fed67ec);
#
#
#         var popup_8a18e4652c083ce3c521546ac9ef8aa9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0202dd0e7f220ae2d7574e13d3a16a92 = $(`&lt;div id=&quot;html_0202dd0e7f220ae2d7574e13d3a16a92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;18 quai de l&#x27;Hôtel de Ville NO-SE&lt;/div&gt;`)[0];
#                 popup_8a18e4652c083ce3c521546ac9ef8aa9.setContent(html_0202dd0e7f220ae2d7574e13d3a16a92);
#
#
#
#         marker_c388adaca43286ad257e007acd9d20f6.bindPopup(popup_8a18e4652c083ce3c521546ac9ef8aa9)
#         ;
#
#
#
#
#             var marker_a932dbdd775b76cc7752e4f029c56002 = L.marker(
#                 [48.85372, 2.3570

# %%
import seaborn as sns

grouped_data = (
    data.groupby(["counter_name", pd.Grouper(freq="1M", key="date")])
    ["log_bike_count"].sum()
    .to_frame()
)
grouped_data = grouped_data.reset_index()
coordinates_mapper = data[['counter_name', 'latitude', 'longitude']].drop_duplicates()
grouped_data = pd.merge(grouped_data, 
                        coordinates_mapper[['counter_name', 'latitude', 'longitude']], 
                        on='counter_name', 
                        how='left')
grouped_data
# Out:
# /var/folders/b3/l_t9dzy13rz2smp7vyx9352h0000gn/T/ipykernel_11038/1192619550.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data.groupby(["counter_name", pd.Grouper(freq="1M", key="date")])
# /var/folders/b3/l_t9dzy13rz2smp7vyx9352h0000gn/T/ipykernel_11038/1192619550.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby(["counter_name", pd.Grouper(freq="1M", key="date")])
#                           counter_name       date  log_bike_count   latitude  \
# 0    152 boulevard du Montparnasse E-O 2020-09-30     2572.257371  48.840801
# 1    152 boulevard du Montparnasse E-O 2020-10-31     2382.779737  48.840801
# 2    152 boulevard du Montparnasse E-O 2020-11-30     2032.810230  48.840801
# 3    152 boulevard du Montparnasse E-O 2020-12-31     2026.296477  48.840801
# 4    152 boulevard du Montparnasse E-O 2021-01-31     1577.473441  48.840801
# ..                                 ...        ...             ...        ...
# 723        Voie Georges Pompidou SO-NE 2021-05-31     2402.760973  48.848400
# 724        Voie Georges Pompidou SO-NE 2021-06-30     2674.675392  48.848400
# 725        Voie Georges Pompidou SO-NE 2021-07-31     2677.705478  48.848400
# 726        Voie Georges Pompidou SO-NE 2021-08-31     2438.580608  48.848400
# 727        Voie Georges Pompidou SO-NE 2021-09-30      822.401780  48.848400
#
#      longitude
# 0     2.333233
# 1     2.333233
# 2     2.333233
# 3     2.333233
# 4     2.333233
# ..         ...
# 723   2.275860
# 724   2.275860
# 725   2.275860
# 726   2.275860
# 727   2.275860
#
# [728 rows x 5 columns]

# %%
import folium
from folium.plugins import TimeSliderChoropleth
from folium.plugins import TimestampedGeoJson
import json
from matplotlib import cm, colors


# Normalize log_bike_count for gradient mapping
log_min, log_max = grouped_data["log_bike_count"].min(), grouped_data["log_bike_count"].max()
norm = colors.Normalize(vmin=log_min, vmax=log_max)

# Create a colormap (e.g., green → yellow → red)
cmap = cm.get_cmap("RdYlGn_r")  # Reverse 'RdYlGn' for red at high values

def get_gradient_color(log_value):
    """Map log_bike_count to a gradient color."""
    rgba_color = cmap(norm(log_value))  # Map normalized value to RGBA
    return colors.rgb2hex(rgba_color[:3])  # Convert to hex color



# Convert DataFrame to GeoJSON-like format
features = [
    {
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": [row["longitude"], row["latitude"]],
        },
        "properties": {
            "time": row["date"].isoformat(),  # Convert to milliseconds
            "icon": "circle",
            "iconstyle": {
                "fillColor": get_gradient_color(row["log_bike_count"]),
                "fillOpacity": 1,
                "stroke": "false",
                "radius": 8,
            },
            "style": {
                "weight": 0,
            },
            "popup": f"Bike Count: {row['log_bike_count']}",
        }
    }
    for _, row in grouped_data.iterrows()
]

geojson_data = {
    "type": "FeatureCollection",
    "features": features,
}

# Initialize a folium map
m = folium.Map(location=data[["latitude", "longitude"]].mean(axis=0), zoom_start=13)

TimestampedGeoJson(
    data=geojson_data,
    period="P1M",  # Time interval for each step (1 month here)
    add_last_point=False,
    auto_play=True,
    loop=True,
    max_speed=10,  # Adjust speed of the animation
    loop_button=True,
    date_options="YYYY-MM",  # Format for the date display (monthly)
    time_slider_drag_update=True,
).add_to(m)

m
# Out:
# /var/folders/b3/l_t9dzy13rz2smp7vyx9352h0000gn/T/ipykernel_11038/2365460358.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("RdYlGn_r")  # Reverse 'RdYlGn' for red at high values
# /opt/homebrew/Caskroom/miniforge/base/envs/bike_counters/lib/python3.13/site-packages/folium/utilities.py:86: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_001d594a02a3908cd2b6038d958d7ffa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_001d594a02a3908cd2b6038d958d7ffa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_001d594a02a3908cd2b6038d958d7ffa = L.map(
#                 &quot;map_001d594a02a3908cd2b6038d958d7ffa&quot;,
#                 {
#                     center: [48.854343481348636, 2.3454791459683153],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ed9f3be5d10a8aae7d9e471ed663d4b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0ed9f3be5d10a8aae7d9e471ed663d4b.addTo(map_001d594a02a3908cd2b6038d958d7ffa);
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format(&quot;YYYY-MM&quot;);
#                 }
#             });
#             map_001d594a02a3908cd2b6038d958d7ffa.timeDimension = L.timeDimension(
#                 {
#                     period: &quot;P1M&quot;,
#                 }
#             );
#             var timeDimensionControl = new L.Control.TimeDimensionCustom(
#                 {&quot;autoPlay&quot;: true, &quot;loopButton&quot;: true, &quot;maxSpeed&quot;: 10, &quot;minSpeed&quot;: 0.1, &quot;playerOptions&quot;: {&quot;loop&quot;: true, &quot;startOver&quot;: true, &quot;transitionTime&quot;: 200}, &quot;position&quot;: &quot;bottomleft&quot;, &quot;speedSlider&quot;: true, &quot;timeSliderDragUpdate&quot;: true}
#             );
#             map_001d594a02a3908cd2b6038d958d7ffa.addControl(this.timeDimensionControl);
#
#             var geoJsonLayer = L.geoJson({&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [2.333233, 48.840801]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2020-09-30T00:00:00&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconstyle&quot;: {&quot;fillColor&quot;: &quot;#fdb96a&quot;, &quot;fillOpacity&quot;: 1, &quot;stroke&quot;: &quot;false&quot;, &quot;radius&quot;: 8}, &quot;style&quot;: {&quot;weight&quot;: 0}, &quot;popup&quot;: &quot;Bike Count: 2572.2573705962677&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [2.333233, 48.840801]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2020-10-31T00:00:00&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconstyle&quot;: {&quot;fillColor&quot;: &quot;#fed27f&quot;, &quot;fillOpacity&quot;: 1, &quot;stroke&quot;: &quot;false&quot;, &quot;radius&quot;: 8}, &quot;style&quot;: {&quot;weight&quot;: 0}, &quot;popup&quot;: &quot;Bike Count: 2382.7797370105463&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [2.333233, 48.840801]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2020-11-30T00:00:00&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconstyle&quot;: {&quot;fillColor&quot;: &quot;#fff5ae&quot;, &quot;fillOpacity&quot;: 1, &quot;stroke&quot;: &quot;false&quot;, &quot;radius&quot;: 8}, &quot;style&quot;: {&quot;weight&quot;: 0}, &quot;popup&quot;: &quot;Bike Count: 2032.8102302403984&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [2.333233, 48.840801]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2020-12-31T00:00:00&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconstyle&quot;: {&quot;fillColor&quot;: &quot;#fff5ae&quot;, &quot;fillOpacity&quot;: 1, &quot;stroke&quot;: &quot;false&quot;, &quot;radius&quot;: 8}, &quot;style&quot;: {&quot;weight&quot;: 0},

# %% [markdown]
# Note that in this challenge, we consider only the 30 most frequented counting sites, to limit data size.
#
# Next we will look into the temporal distribution of the most frequented bike counter. If we plot it directly we will not see much because there are half a million data points:
